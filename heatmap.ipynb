# %%
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2
import heatgraphy as hg

import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = np.random.randint(0, 10, (10, 10))
bar_data = np.random.randint(0, 100, 10)
color_data = [0.1 for _ in range(5)] + [0.2 for _ in range(5)]

# %%
figure = plt.figure()
g = hg.Grid()
g.top("top1")
g.filled_split("top1", x=[0.3, 0.8], wspace=0.05)
g.split("main", x=[0.3, 0.8], wspace=0.2)
g.freeze(figure)
# Out:
# SubLayout(row=1, col=3, wspace=0.2, hspace=0.05, mode='blank', w_ratios=[1.5, 2.5, 1.0], h_ratios=None, ax_labels=[])
# SubLayout(row=1, col=5, wspace=0, hspace=0, mode='blank', w_ratios=[0.27499999999999997, 0.050000000000000044, 0.45, 0.050000000000000044, 0.17499999999999993], h_ratios=None, ax_labels=[])

# %%
h = hg.Heatmap(data)
h.render()

# %%
h = hg.Heatmap(data)
h.split(x=[5], wspace=0)
#h.add_colors("top", np.array([color_data]), size=0.5)
#h.add_bar("top", bar_data)
h.render()
# Out:
# SubLayout(row=1, col=2, wspace=0, hspace=0.05, w_ratios=[2.5, 2.5], h_ratios=None)

# %%
g = hg.Grid()
g.top("dendrogram")
g.split("main", x=[0.5], wspace=1)

# %%
fig = plt.figure()
g.freeze(figure=fig)
heat_axes = g.get_ax("main")
dax = g.get_ax("dendrogram")
hax0 = heat_axes[0]
hax0.set_xlim(0, 5)
hax0.hlines(0.5, 0, 10)
heat_axes[1].set_xlim(5, 10)

# %%
plt.vline?
# Out:
# Object `plt.vline` not found.
